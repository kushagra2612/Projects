# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
td  = pd.read_csv('Transformed_Housing_Data.csv')

# %%
td.head()
# Out:
#            ID  Sale Price  No of Bedrooms  No of Bathrooms  \
# 0  7129300520    221900.0               3             1.00
# 1  6414100192    538000.0               3             2.25
# 2  5631500400    180000.0               2             1.00
# 3  2487200875    604000.0               4             3.00
# 4  1954400510    510000.0               3             2.00
#
#    Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors Waterfront View  \
# 0               1180.0              5650.0           1.0              No
# 1               2570.0              7242.0           2.0              No
# 2                770.0             10000.0           1.0              No
# 3               1960.0              5000.0           1.0              No
# 4               1680.0              8080.0           1.0              No
#
#    No of Times Visited Condition of the House  ...  \
# 0                    0                   Fair  ...
# 1                    0                   Fair  ...
# ...

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

# %%
td  = td.rename(columns = {'Sale Price' : 'Sale_Price'})

# %%
td  = td.rename(columns = {'Condition of the House' : 'Condition_of_the_House'})

# %%
td  = td.rename(columns = {'Ever Renovated' : 'Ever_Renovated'})

# %%
td  = td.rename(columns = {'Waterfront View' : 'Waterfront_View'})

# %%
td.head()
# Out:
#            ID  Sale_Price  No of Bedrooms  No of Bathrooms  \
# 0  7129300520    221900.0               3             1.00
# 1  6414100192    538000.0               3             2.25
# 2  5631500400    180000.0               2             1.00
# 3  2487200875    604000.0               4             3.00
# 4  1954400510    510000.0               3             2.00
#
#    Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors Waterfront_View  \
# 0               1180.0              5650.0           1.0              No
# 1               2570.0              7242.0           2.0              No
# 2                770.0             10000.0           1.0              No
# 3               1960.0              5000.0           1.0              No
# 4               1680.0              8080.0           1.0              No
#
#    No of Times Visited Condition_of_the_House  ...  \
# 0                    0                   Fair  ...
# 1                    0                   Fair  ...
# ...

# %%
td['Waterfront_View'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
mod = ols('Sale_Price ~ Condition_of_the_House', data  = td).fit()

# %%
Anova_Table = sm.stats.anova_lm( mod, typ = 2)

# %%
print(Anova_Table)
# Out:
#                               sum_sq       df         F        PR(>F)
# Condition_of_the_House  1.441831e+13      4.0  58.25563  5.447605e-49
# Residual                1.336752e+15  21604.0       NaN           NaN

# %%
mod = ols('Sale_Price ~ Waterfront_View', data  = td).fit()
sm.stats.anova_lm( mod, typ = 2)
# Out:
#                        sum_sq       df           F         PR(>F)
# Waterfront_View  3.283737e+13      1.0  538.192683  1.275558e-117
# Residual         1.318333e+15  21607.0         NaN            NaN

# %%
mod = ols('Sale_Price ~ Ever_Renovated', data  = td).fit()
sm.stats.anova_lm( mod, typ = 2)
# Out:
#                       sum_sq       df           F        PR(>F)
# Ever_Renovated  1.998463e+13      1.0  324.378469  5.419055e-72
# Residual        1.331185e+15  21607.0         NaN           NaN

# %%
mod = ols('Sale_Price ~ Zipcode', data  = td).fit()
sm.stats.anova_lm( mod, typ = 2)
# Out:
#                 sum_sq       df          F        PR(>F)
# Zipcode   2.503765e+12      1.0  40.112844  2.444308e-10
# Residual  1.348666e+15  21607.0        NaN           NaN

# %%
td = pd.get_dummies(td, columns = ['Condition_of_the_House'], drop_first = True)

# %%
td.head()
# Out:
#            ID  Sale_Price  No of Bedrooms  No of Bathrooms  \
# 0  7129300520    221900.0               3             1.00
# 1  6414100192    538000.0               3             2.25
# 2  5631500400    180000.0               2             1.00
# 3  2487200875    604000.0               4             3.00
# 4  1954400510    510000.0               3             2.00
#
#    Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors Waterfront_View  \
# 0               1180.0              5650.0           1.0              No
# 1               2570.0              7242.0           2.0              No
# 2                770.0             10000.0           1.0              No
# 3               1960.0              5000.0           1.0              No
# 4               1680.0              8080.0           1.0              No
#
#    No of Times Visited  Overall Grade  ...  Latitude  Longitude  \
# 0                    0              7  ...   47.5112   -122.257
# ...

# %%
td = pd.get_dummies(td, columns = ['Ever_Renovated', 'Waterfront_View'], drop_first = True)

# %%
td.head()
# Out:
#            ID  Sale_Price  No of Bedrooms  No of Bathrooms  \
# 0  7129300520    221900.0               3             1.00
# 1  6414100192    538000.0               3             2.25
# 2  5631500400    180000.0               2             1.00
# 3  2487200875    604000.0               4             3.00
# 4  1954400510    510000.0               3             2.00
#
#    Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  No of Times Visited  \
# 0               1180.0              5650.0           1.0                    0
# 1               2570.0              7242.0           2.0                    0
# 2                770.0             10000.0           1.0                    0
# 3               1960.0              5000.0           1.0                    0
# 4               1680.0              8080.0           1.0                    0
#
#    Overall Grade  Area of the House from Basement (in Sqft)  ...  Longitude  \
# ...

# %%
# Zip_Table
ZT = td.groupby('Zipcode').agg({'Sale_Price' : 'mean'}).sort_values('Sale_Price', ascending = True)

# %%
ZT.head()
# Out:
#             Sale_Price
# Zipcode
# 98002.0  234284.035176
# 98168.0  240328.371747
# 98032.0  251296.240000
# 98001.0  280804.690608
# 98148.0  284908.596491

# %%
ZT['Zipcode_Group'] = pd.cut(ZT['Sale_Price'],bins = 10, 
                             labels = ['Zipcode_Group_0',
                                      'Zipcode_Group_1',
                                      'Zipcode_Group_2',
                                      'Zipcode_Group_3',
                                      'Zipcode_Group_4',
                                      'Zipcode_Group_5',
                                      'Zipcode_Group_6',
                                      'Zipcode_Group_7',
                                      'Zipcode_Group_8',
                                      'Zipcode_Group_9'],
                            include_lowest = True)

# %%
ZT = ZT.drop(columns = "Sale_Price")

# %%
td = pd.merge(td,ZT,left_on = 'Zipcode', how = 'left', right_index = True)

# %%
td = td.drop(columns = "Zipcode")

# %%
td.head()
# Out:
#            ID  Sale_Price  No of Bedrooms  No of Bathrooms  \
# 0  7129300520    221900.0               3             1.00
# 1  6414100192    538000.0               3             2.25
# 2  5631500400    180000.0               2             1.00
# 3  2487200875    604000.0               4             3.00
# 4  1954400510    510000.0               3             2.00
#
#    Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  No of Times Visited  \
# 0               1180.0              5650.0           1.0                    0
# 1               2570.0              7242.0           2.0                    0
# 2                770.0             10000.0           1.0                    0
# 3               1960.0              5000.0           1.0                    0
# 4               1680.0              8080.0           1.0                    0
#
#    Overall Grade  Area of the House from Basement (in Sqft)  ...  \
# 0              7                                     1180.0  ...
# ...

# %%
td = pd.get_dummies(td, columns = ['Zipcode_Group'], drop_first = True)

# %%
td.head()
# Out:
#            ID  Sale_Price  No of Bedrooms  No of Bathrooms  \
# 0  7129300520    221900.0               3             1.00
# 1  6414100192    538000.0               3             2.25
# 2  5631500400    180000.0               2             1.00
# 3  2487200875    604000.0               4             3.00
# 4  1954400510    510000.0               3             2.00
#
#    Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  No of Times Visited  \
# 0               1180.0              5650.0           1.0                    0
# 1               2570.0              7242.0           2.0                    0
# 2                770.0             10000.0           1.0                    0
# 3               1960.0              5000.0           1.0                    0
# 4               1680.0              8080.0           1.0                    0
#
#    Overall Grade  Area of the House from Basement (in Sqft)  ...  \
# 0              7                                     1180.0  ...
# ...
